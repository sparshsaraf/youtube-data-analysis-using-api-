# %%
pip install google-api-python-client
# Out:
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ----- ---------------------------------- 1.8/12.3 MB 11.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.4/12.3 MB 10.1 MB/s eta 0:00:01
#    ------------------ --------------------- 5.8/12.3 MB 9.8 MB/s eta 0:00:01
#    --------------------- ------------------ 6.6/12.3 MB 8.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.8/12.3 MB 7.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.1/12.3 MB 6.2 MB/s eta 0:00:01
#    ------------------------ --------------- 7.6/12.3 MB 5.2 MB/s eta 0:00:01
#    -------------------------- ------------- 8.1/12.3 MB 4.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.7/12.3 MB 4.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.2/12.3 MB 4.4 MB/s eta 0:00:01
#    -------------------------------- ------- 10.0/12.3 MB 4.3 MB/s eta 0:00:01
# ...

# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key = "AIzaSyDBgUV7Se7935L3INcaRZTeiniLcp0CAEE"
channel_ids =['UCbKWv2x9t6u8yZoB3KcPtnw',
              'UCBJycsmduvYEL83R_U4JriQ',
              'UCaTTPj9mnvMal75qwybVxRg',
              'UCjgpFI5dU-D1-kh9H1muoxQ',
              'UCUCeZaZeJbEYAAzvMgrKOPQ',
             ]
              



youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# ##Function to get channel statistics

# %%
deget_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
        part='snippet,contentDetails,statistics',
        id=','.join(channel_ids))f 
    response = request.execute()
    for i in range(len(response['items'])):

        data = dict(Channel_name =response['items'][i]['snippet']['title'],
                    Subscribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics']['viewCount'],
                    Total_videos = response['items'][i]['statistics']['videoCount'],
                    playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return all_data

# %%
channel_statistics = get_channel_stats(youtube, channel_ids)

# %%
channel_data = pd.DataFrame(channel_statistics)

# %%
channel_data
# Out:
#                Channel_name Subscribers       Views Total_videos  \
# 0       Kenshi Yonezu  米津玄師     7380000  6124817600          189
# 1      Hacksmith Industries    15100000  2719489918         1167
# 2          Marques Brownlee    19600000  4536159018         1688
# 3  Codfish - Boots n' cats!     2140000   156656762           91
# 4               Alan Becker    29100000  7523965707          214
#
#                 playlist_id
# 0  UUUCeZaZeJbEYAAzvMgrKOPQ
# 1  UUjgpFI5dU-D1-kh9H1muoxQ
# 2  UUBJycsmduvYEL83R_U4JriQ
# 3  UUaTTPj9mnvMal75qwybVxRg
# 4  UUbKWv2x9t6u8yZoB3KcPtnw

# %%
channel_data.dtypes #we have to convert into integers rather than object to vizualize them
# Out:
# Channel_name    object
# Subscribers     object
# Views           object
# Total_videos    object
# playlist_id     object
# dtype: object

# %%
channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'])
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# Total_videos     int64
# playlist_id     object
# dtype: object

# %%
sns.set(rc={'figure.figsize':(10,8)})
ax = sns.barplot(x='Channel_name', y ='Subscribers',data=channel_data)
# Out:
# C:\Users\Intro\anaconda3\envs\YT-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 31859 (\N{CJK UNIFIED IDEOGRAPH-7C73}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Users\Intro\anaconda3\envs\YT-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 27941 (\N{CJK UNIFIED IDEOGRAPH-6D25}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Users\Intro\anaconda3\envs\YT-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 29572 (\N{CJK UNIFIED IDEOGRAPH-7384}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Users\Intro\anaconda3\envs\YT-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 24107 (\N{CJK UNIFIED IDEOGRAPH-5E2B}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Users\Intro\anaconda3\envs\YT-env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 31859 (\N{CJK UNIFIED IDEOGRAPH-7C73}) missing from font(s) Arial.
# ...

# %%
ax = sns.barplot(x='Channel_name', y ='Views',data=channel_data,palette='viridis')
# Out:
# C:\Users\Intro\AppData\Local\Temp\ipykernel_9060\2316912169.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Channel_name', y ='Views',data=channel_data,palette='viridis')
# C:\Users\Intro\anaconda3\envs\YT-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 31859 (\N{CJK UNIFIED IDEOGRAPH-7C73}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Users\Intro\anaconda3\envs\YT-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 27941 (\N{CJK UNIFIED IDEOGRAPH-6D25}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Users\Intro\anaconda3\envs\YT-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 29572 (\N{CJK UNIFIED IDEOGRAPH-7384}) missing from font(s) Arial.
#   func(*args, **kwargs)
# ...

# %%
ax = sns.barplot(x='Channel_name', y ='Total_videos',data=channel_data, palette='viridis')
# Out:
# C:\Users\Intro\AppData\Local\Temp\ipykernel_9060\3548016114.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Channel_name', y ='Total_videos',data=channel_data, palette='viridis')
# C:\Users\Intro\anaconda3\envs\YT-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 31859 (\N{CJK UNIFIED IDEOGRAPH-7C73}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Users\Intro\anaconda3\envs\YT-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 27941 (\N{CJK UNIFIED IDEOGRAPH-6D25}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Users\Intro\anaconda3\envs\YT-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 29572 (\N{CJK UNIFIED IDEOGRAPH-7384}) missing from font(s) Arial.
#   func(*args, **kwargs)
# ...

# %% [markdown]
# ##Function to get the video ids

# %%
channel_data
# Out:
#                Channel_name  Subscribers       Views  Total_videos  \
# 0       Kenshi Yonezu  米津玄師      7380000  6124817600           189
# 1      Hacksmith Industries     15100000  2719489918          1167
# 2          Marques Brownlee     19600000  4536159018          1688
# 3  Codfish - Boots n' cats!      2140000   156656762            91
# 4               Alan Becker     29100000  7523965707           214
#
#                 playlist_id
# 0  UUUCeZaZeJbEYAAzvMgrKOPQ
# 1  UUjgpFI5dU-D1-kh9H1muoxQ
# 2  UUBJycsmduvYEL83R_U4JriQ
# 3  UUaTTPj9mnvMal75qwybVxRg
# 4  UUbKWv2x9t6u8yZoB3KcPtnw

# %%
playlist_id = channel_data.loc[channel_data['Channel_name']=='Alan Becker', 'playlist_id'].iloc[0]

# %%
def get_video_ids(youtube, playlist_id):

    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 50)
    response = request.execute()
    
    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True 

    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()

            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])

            next_page_token = response.get('nextPageToken')
            
        

    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
video_ids
# Out:
# ['GTYIQ-MUk7E',
#  'Qg1FcfQv-WI',
#  'CYhGhs0Ismk',
#  '0m1HmcbBmjs',
#  '1Y7NgROVFWk',
#  'i6fwSzRiEJM',
#  'xrpieJz6qiE',
#  'b22ZMmkGfEM',
#  'MSUwAIZ7QgM',
#  'NTJd6G4Vd2g',
#  'cgI5n5v2-UA',
#  'VEJWE6cpqw0',
#  'WwKY_JPSSs4',
#  '7iO9sIrEcRw',
#  'w0bYgvYokFM',
#  'DaBu3XrMayI',
#  '8oqYkEr3rTg',
#  'vSOgORxufW8',
#  'SeyBYD0B2BY',
#  'CvfldRjkmW0',
#  'k9VS5QLULHc',
#  'j49k8p3Sd1s',
#  'YMLC8iudXWI',
#  '4BQtlK4nMrE',
#  'Dz3za8cdwqM',
#  'WthdgXPPhy8',
#  'LDJCMHqISfw',
#  'vlVUVsx6BYY',
#  'RqhGnw-4TeQ',
#  'ErMSHiQRnc8',
#  '2pM1PrWbcV8',
#  'P2z7NkwhVGk',
#  'jJWMzq4gdnc',
#  '3DSkcmAEjH4',
#  'OPo5_EBO5JM',
#  'oPAIoyMCoOY',
#  'c2IwDLj9o4Q',
#  'UcHTOtUVUV4',
#  'UgjNVue2_Gk',
#  'z69EUIbOFlk',
#  'OZT001NY6bI',
#  '7UPEJjZ0UAE',
#  'gBdjZ4gR4A4',
#  'r9YcPibYYc4',
#  'RIQu-uks6Bs',
#  'iBzLtNUspY0',
#  'Czdsu1Oi6vE',
#  'i5IhxDoA6KU',
#  'JkUv2UHKPss',
#  'VKXMICY7l_g',
#  'gQp-2HUy_EI',
#  'bKMkw4vazgE',
#  'mjvrDdwsSQw',
#  'B1J6Ou4q8vE',
#  'URVAqg4tEjQ',
# ...

# %% [markdown]
# ##fucntion to get video details

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []
    for i in range(0, len(video_ids),50):
        request = youtube.videos().list(
                    part='snippet,statistics',
                    id =','.join(video_ids[i:i+50]))
        response = request.execute()

        for video in response['items']:
            video_stats = dict(Title = video['snippet']['title'],
                              Published_date = video['snippet']['publishedAt'],
                              Views = video['statistics']['viewCount'],
                              Likes = video['statistics']['likeCount'],
                              Comments = video['statistics']['commentCount']
                              )
            all_video_stats.append(video_stats)

    return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)

# %%
video_data = pd.DataFrame(video_details)

# %%
video_data['Published_date'] = pd.to_datetime(video_data['Published_date']).dt.date
video_data['views'] = pd.to_numeric(video_data['Views'])
video_data['Likes'] = pd.to_numeric(video_data['Likes'])
video_data['Comments'] = pd.to_numeric(video_data['Comments'])
video_data
# Out:
#                                       Title Published_date     Views    Likes  \
# 0    Bob from the Shadows - An Actual Short     2024-10-26    883283   103950
# 1            Burnout – Influencer Arc Ep. 3     2024-10-19   2808671   134739
# 2          Alan Becker TV - 24/7 Livestream     2024-10-09   1779420    35642
# 3    IS GREEN OKAY!? – Influencer Arc Ep. 2     2024-10-05   3731863   173114
# 4          Red’s Speedrun - An Actual Short     2024-09-21  10073883   537405
# ..                                      ...            ...       ...      ...
# 208       Animator vs. Animation (original)     2007-05-15  87188889  1471369
# 209     Animator vs. Animation 2 (original)     2007-05-15  26936848   386012
# 210                      Stop Motion - Worm     2007-04-09   3981727   132130
# 211                                 Machine     2007-01-22   1439550    36244
# 212                   Trampoline time-lapse     2006-12-25   3414961    96410
#
#      Comments     views
# ...

# %%
top10_videos = video_data.sort_values(by='Views', ascending=False).head(10)

# %%
top10_videos
# Out:
#                                                 Title Published_date  \
# 98  Monster School - Animation vs. Minecraft Short...     2022-03-05
# 79                        Fireworks - An Actual Short     2022-12-31
# 80                      Ice Skating - An Actual Short     2022-12-24
# 62                                           A Teaser     2023-04-23
# 77                  Fishing Trouble - An Actual Short     2023-01-14
# 68                   Wipeout Course - An Actual Short     2023-03-18
# 63                    New Wallpaper - An Actual Short     2023-04-22
# 6                   Cartoon Physics - An Actual Short     2024-08-31
# 15                   Onion Skinning - An Actual Short     2024-05-18
# 64                  Cherry Blossoms - An Actual Short     2023-04-15
#
#        Views    Likes  Comments     views
# 98  98231777  1195033     36534  98231777
# 79   9767310   757521     11424   9767310
# 80   9680612   764068      7111   9680612
# ...

# %%
ax1 = sns.barplot(x='Views', y='Title', data=top10_videos, orient = "h", palette='viridis' )
# Out:
# C:\Users\Intro\AppData\Local\Temp\ipykernel_9060\3431821779.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax1 = sns.barplot(x='Views', y='Title', data=top10_videos, orient = "h", palette='viridis' )

# %%
video_data
# Out:
#                                       Title Published_date     Views    Likes  \
# 0    Bob from the Shadows - An Actual Short     2024-10-26    883283   103950
# 1            Burnout – Influencer Arc Ep. 3     2024-10-19   2808671   134739
# 2          Alan Becker TV - 24/7 Livestream     2024-10-09   1779420    35642
# 3    IS GREEN OKAY!? – Influencer Arc Ep. 2     2024-10-05   3731863   173114
# 4          Red’s Speedrun - An Actual Short     2024-09-21  10073883   537405
# ..                                      ...            ...       ...      ...
# 208       Animator vs. Animation (original)     2007-05-15  87188889  1471369
# 209     Animator vs. Animation 2 (original)     2007-05-15  26936848   386012
# 210                      Stop Motion - Worm     2007-04-09   3981727   132130
# 211                                 Machine     2007-01-22   1439550    36244
# 212                   Trampoline time-lapse     2006-12-25   3414961    96410
#
#      Comments     views
# ...

# %%
video_data['Month'] = pd.to_datetime(video_data['Published_date']).dt.strftime('%b')

# %%
video_data
# Out:
#                                       Title Published_date     Views    Likes  \
# 0    Bob from the Shadows - An Actual Short     2024-10-26    883283   103950
# 1            Burnout – Influencer Arc Ep. 3     2024-10-19   2808671   134739
# 2          Alan Becker TV - 24/7 Livestream     2024-10-09   1779420    35642
# 3    IS GREEN OKAY!? – Influencer Arc Ep. 2     2024-10-05   3731863   173114
# 4          Red’s Speedrun - An Actual Short     2024-09-21  10073883   537405
# ..                                      ...            ...       ...      ...
# 208       Animator vs. Animation (original)     2007-05-15  87188889  1471369
# 209     Animator vs. Animation 2 (original)     2007-05-15  26936848   386012
# 210                      Stop Motion - Worm     2007-04-09   3981727   132130
# 211                                 Machine     2007-01-22   1439550    36244
# 212                   Trampoline time-lapse     2006-12-25   3414961    96410
#
#      Comments     views Month
# ...

# %%
videos_per_month = video_data.groupby('Month', as_index = False).size()

# %%
videos_per_month # now to sort
# Out:
#    Month  size
# 0    Apr    18
# 1    Aug    15
# 2    Dec    33
# 3    Feb    10
# 4    Jan    15
# 5    Jul    19
# 6    Jun    14
# 7    Mar    14
# 8    May    18
# 9    Nov    18
# 10   Oct    22
# 11   Sep    17

# %%
sort_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
videos_per_month.index = pd.CategoricalIndex(videos_per_month['Month'], categories = sort_order, ordered=True)

# %%
videos_per_month = videos_per_month.sort_index()
#now to vizualize how many videos are posted per month

# %%
ax2 = sns.barplot(x='Month', y='size', data=videos_per_month, palette='viridis')
# Out:
# C:\Users\Intro\AppData\Local\Temp\ipykernel_9060\3200277499.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax2 = sns.barplot(x='Month', y='size', data=videos_per_month, palette='viridis')

# %%
video_data
# Out:
#                                       Title Published_date     Views    Likes  \
# 0    Bob from the Shadows - An Actual Short     2024-10-26    883283   103950
# 1            Burnout – Influencer Arc Ep. 3     2024-10-19   2808671   134739
# 2          Alan Becker TV - 24/7 Livestream     2024-10-09   1779420    35642
# 3    IS GREEN OKAY!? – Influencer Arc Ep. 2     2024-10-05   3731863   173114
# 4          Red’s Speedrun - An Actual Short     2024-09-21  10073883   537405
# ..                                      ...            ...       ...      ...
# 208       Animator vs. Animation (original)     2007-05-15  87188889  1471369
# 209     Animator vs. Animation 2 (original)     2007-05-15  26936848   386012
# 210                      Stop Motion - Worm     2007-04-09   3981727   132130
# 211                                 Machine     2007-01-22   1439550    36244
# 212                   Trampoline time-lapse     2006-12-25   3414961    96410
#
#      Comments     views Month
# ...

# %%
video_data.to_csv('Video_Details(author).csv')
